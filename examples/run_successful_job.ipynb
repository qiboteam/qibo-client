# %%
import time
from pathlib import Path

import qibo

from qibo_client import Client

# create the circuit you want to run
num_qubits = 5
circuit = qibo.Circuit(num_qubits)
circuit.add(qibo.gates.GPI2(0, 0.0))
circuit.add(qibo.gates.GPI2(1, 0.0))
circuit.add(qibo.gates.GPI2(2, 0.0))
circuit.add(qibo.gates.M(0, 1, 2))

wire_names = [f"A{i}" for i in range(1, num_qubits + 1)]

circuit.draw()

# read the token from file
token_path = Path(".").cwd() / "token.txt"
token = token_path.read_text()

# authenticate to server through the client instance
client = Client(token)

# run the circuit
start = time.time()
job = client.run_circuit(circuit, device="tii-sim", project="personal", nshots=150)
print(job.result(wait=0.5, verbose=True))
# Out:
# [2025-10-09 15:28:40,209] WARNING: Note: ipywidgets is not installed. Falling back to standard logging. Install with: `pip install ipywidgets` to enable the Rich UI.
# 0: ─H─U1─U1─U1─U1───────────────────────────x───M─
# 1: ───o──|──|──|──H─U1─U1─U1────────────────|─x─M─
# 2: ──────o──|──|────o──|──|──H─U1─U1────────|─|─M─
# 3: ─────────o──|───────o──|────o──|──H─U1───|─x───
# 4: ────────────o──────────o───────o────o──H─x─────
# [2025-10-09 15:28:40,902] INFO: 🚀 Starting qibo client...
# [2025-10-09 15:28:40,904] INFO: 📬 Job posted on tii-sim	 pid, 7f39196377304468a307c7f88068f91a
# [2025-10-09 15:28:41,032] INFO: 🕒 Job PENDING
# [2025-10-09 15:28:42,373] INFO: 🕒 Job PENDING -> position in queue: 1, max ETD: 0:05:00
# [2025-10-09 15:28:58,188] INFO: 🚀 Job RUNNING
# [2025-10-09 15:29:03,580] INFO: ✅ Job SUCCESS
# [2025-10-09 15:29:03,582] INFO: Job COMPLETED
# (0.17678+0j)|00000> + (0.17678+0j)|00001> + (0.17678+0j)|00010> + (0.17678+0j)|00011> + (0.17678+0j)|00100> + (0.17678+0j)|00101> + (0.17678+0j)|00110> + (0.17678+0j)|00111> + (0.17678+0j)|01000> + (0.17678+0j)|01001> + (0.17678+0j)|01010> + (0.17678+0j)|01011> + (0.17678+0j)|01100> + (0.17678+0j)|01101> + (0.17678+0j)|01110> + (0.17678+0j)|01111> + (0.17678+0j)|10000> + (0.17678+0j)|10001> + (0.17678+0j)|10010> + (0.17678+0j)|10011> + ...
